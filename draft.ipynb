# %%
import nltk
import pymorphy2
import string
morph = pymorphy2.MorphAnalyzer()

# %%
sting = string.punctuation + '1234567890qwertyuiopasdfghjklzxcvbnm'

# %%
filepath = r"C:\Users\Пользователь\универ\infos\friends-data\Friends - season 7\Friends - 7x01 - The One With Monica's Thunder.ru.txt"
words = {}
with open(filepath, 'r', encoding = 'UTF-8') as f:   
    text = f.read().lower()
text = text[1:]
for s in sting:
    text = text.replace(s,'')
pretext = nltk.word_tokenize(text) 
for i, p in enumerate(pretext):   
    pretext[i] = morph.parse(p)[0][2] 
    p = pretext[i]
    if p not in words:
        words[p] = {}
        words[p][filepath] = 1
    else:
        words[p][filepath] += 1
line = ' '.join(pretext)
print(line)
# Out:
# привет что случиться я найти на дверь записка приходить к моника захватить шампанский и батончик три мушкетёр да это я что случиться мы с моника помолвить о бог поздравлять где она я обручить я обручить она там уже минута ты не слышать я думать ктоть кричать я обречь позвать её нет пускай побыть там это так мило я выходить замуж я быть невеста заткнуться нет я не заткнуться потому что я обручить напугать мочь подняться сюда и сказать я это в лицо мой жених надраться ты зад давать квартира я квартира ты тащить её сюда ты запереть дверь я быть в шкаф тактактак просто хотеть сказать я вы очень любить ребята спасибо что прислать в столь особенный для я вечер для мы вечер он бы не быть такой особенный для я для мы если бы вы не праздновать он вместе с я с мы черта весь нормальный я тоже хотеть чтобы этот вечер быть только твой за моника да ладный вы перестать ладный за моника ты уже решить кто быть играть на свадьба ведь я тоже музыкант они обручиться всего пара часы назад вряд ли у она быть время хотеть поговорить рассказать ещё раз как ты спалить мой квартира разбираться сам давать приодеться и пойти пить шампанский в плаз только я ненадолго я рано вставать у я прослушивание нужно хорошо выглядеть я играть летний что значит когда ты говорить встать ранний ты иметь в вид в ом вы ребята думать что я не выглядеть на оу мы думать ты сказать ладный весь давать собираться никто не видеть мой шоколадка нет ты весь её съесть это я и бояться знаешь какой туфля быть великолепно смотреться с это кольцо бриллиантовый туфля ты не одеваться ты я понимать да но бояться у мы нет время у мы быть свадьба ты быть невеста и человек быть смотреть на ты в чистый бел платье идти сюда чендлера это с многий случается ты устать ты выпить много шампанский не волноваться насчёт это я не волноваться я поражаться знаешь это ведь биология что забавно потому что в старший класс я провалить биология а сегодня биология ответить я тем же послушать я мочь это играть пока гость собираться итак встретить я чендлера решить что он гей но я поить он к алтарь идти вместе с она фиби нет если бы ты дать я закончить то я бы спеть что он возможно не гей у вы парень нет этот проблема вы сделать из дерево привет отлично выглядеть спасибо с ты весь в порядок даже не знать я немного а знаешь неважно весь хорошо не переживать ты наверное устать выпить много шампанский это с весь случается счастливый ты вечер моника спасибо ты тот тоже ты мочь поверить что они действительно жениться да конечно но ято жениться постоянно ты в порядок думать да как ты думать с мы когданибудь это произойти под мы ты иметь в вид ты и я нет нет нет у ты с кемнибыть у я с кемнибыть хорошо а то я уж испугаться я знать это в прошлое я и ты мы вместе это быть просто кошмар хотя быть и хороший безусловно например я уверенный ты чтонибыть вспомнить подождать минутка ах да конечно я вспомнить коечто хороший ты быть всегда хороший в это я быть хороший в это я нравиться твой рука мой рука молодец ребята и ты тоже быть в это хороший да я знать знаешь что у мы никогда не быть я не о это у мы никогда не быть премиальный ночь что премиальный ночь когда два человек расставаться но потом встречаться на один ночь на один ночь только секс никакой обязательство да у мы не быть такой не быть да мы кажется сходить с ум наверняка это быть бы незабываемый но я думать это не самый удачный мысль очень очень не удачный кагдил кагдил чувак забирать весь что хотеть только не делать я больно ты рубиться в да это отстой это отстой кагдил с отстойный чувак ну я или как да по шкала от до где как максимально подурацки мочь выглядеть человек ты определённо да ладный как я выглядеть молодо ты мужчинаребёнка хорошо а теперь переодеваться весь уже готовый и умолять оставить себя мой трус спасибо ты ведь много секс заниматься да когда сегодня ну не очень я ты спрашивать потому что у я быть чтоть вроде я быть не в состояние я правда хотеть но не смочь у я быть несчастный случай не волноваться насчёт это бывать это быть и с ты да один раз и  ...

# %%
vectorizer.get_feature_names()  # ['слово1', 'слово2', 'слово3', 'слово4']
 
# чтобы узнать индекс токена в словаре
vectorizer.vocabulary_.get('слово3') # вернет 2
 
# показать матрицу
X.toarray()
 
# теперь можно быстро подсчитать вектор для нового документа
vectorizer.transform(["слово1 слово4 слово4"])  # результат [[1 0 0 2]]
 
# чтобы узнать количественное вхождение каждого слова:
matrix_freq = np.asarray(X.sum(axis=0)).ravel()
final_matrix = np.array([np.array(vectorizer.get_feature_names()), matrix_freq])
